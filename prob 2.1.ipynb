# %%
#code from https://www.geeksforgeeks.org/implementation-k-nearest-neighbors/
import math
from random import shuffle
f=open("iris.data","r")
fl=f.read().splitlines()
f.close()
    # Split the first line by commas,  
    # remove the first element and save 
    # the rest into a list. The list  
    # holds the feature names of the  
    # data set. 
features = fl[0].split(', ')[:-1] 


items=[]
for i in range(1,len(fl)):
    line=fl[i].split(', ')

    itemFeatures={"Class" : line[-1]}
    itemFeatures

    for j in range(len(features)):
        f=features[j]
        v=float(line[j])
        itemFeatures[f]=v
    
    items.append(itemFeatures)
shuffle(items)

print(items)
def EuclideanDistance(x, y): 
      
    # The sum of the squared  
    # differences of the elements 
    S = 0;  
      
    for key in x.keys(): 
        S += math.pow(x[key]-y[key], 2); 
  
    # The square root of the sum 
    return math.sqrt(S); 




def UpdateNeighbors(neighbors, item, distance, k): 
      
    if(len(neighbors) > distance): 
              
            # If yes, replace the last 
            # element with new item 
            neighbors[-1] = [distance, item["Class"]]; 
            neighbors = sorted(neighbors); 
  
    return neighbors; 





def CalculateNeighborsClass(neighbors, k): 
    count = {}; 
      
    for i in range(k): 
          
        if(neighbors[i][1] not in count): 
          
            # The class at the ith index 
            # is not in the count dict. 
            # Initialize it to 1. 
            count[neighbors[i][1]] = 1; 
        else: 
              
            # Found another item of class  
            # c[i]. Increment its counter. 
            count[neighbors[i][1]] += 1; 
  
    return count; 



def FindMax(countList): 
      
    # Hold the max 
    maximum = -1; 
      
    # Hold the classification 
    classification = "";  
      
    for key in countList.keys(): 
        
        if(countList[key] > maximum): 
            maximum = countList[key]; 
            classification = key; 
  
    return classification, maximum;
# Out:
# [{'Class': '5.1,3.8,1.6,0.2,Iris-setosa'}, {'Class': '5.6,3.0,4.5,1.5,Iris-versicolor'}, {'Class': '6.7,3.1,4.4,1.4,Iris-versicolor'}, {'Class': '5.0,2.3,3.3,1.0,Iris-versicolor'}, {'Class': '6.4,2.8,5.6,2.1,Iris-virginica'}, {'Class': '6.4,2.8,5.6,2.2,Iris-virginica'}, {'Class': '5.8,2.7,4.1,1.0,Iris-versicolor'}, {'Class': '6.5,2.8,4.6,1.5,Iris-versicolor'}, {'Class': '6.0,2.9,4.5,1.5,Iris-versicolor'}, {'Class': '4.9,2.5,4.5,1.7,Iris-virginica'}, {'Class': '5.5,2.4,3.7,1.0,Iris-versicolor'}, {'Class': '6.3,2.3,4.4,1.3,Iris-versicolor'}, {'Class': '5.8,2.6,4.0,1.2,Iris-versicolor'}, {'Class': '5.4,3.4,1.7,0.2,Iris-setosa'}, {'Class': '7.9,3.8,6.4,2.0,Iris-virginica'}, {'Class': '4.9,3.0,1.4,0.2,Iris-setosa'}, {'
3,Iris-setosa'}, {'Class': '5.5,2.4,3.8,1.1,Iris-versicolor'}, {'Class': '7.7,2.8,6.7,2.0,Iris-virginica'}, {'Class': '6.6,2.9,4.6,1.3,Iris-versicolor'}, {'Class': '6.1,2.8,4.7,1.2,Iris-versicolor'}, {'Class': '5.0,3.4,1.5,0.2,Iris-setosa'}, {'Class': '7.2,3.2,6.0,1.8,Iris-virginica'}, {'Class': '7.0,3.2,4.7,1.4,Iris-versicolor'}, {'Class': '5.0,3.0,1.6,0.2,Iris-setosa'}, {'Class': '6.3,3.4,5.6,2.4,Iris-virginica'}, {'Class': ''}, {'Class': '6.7,3.1,4.7,1.5,Iris-versicolor'}, {'Class': '7.1,3.0,5.9,2.1,Iris-virginica'}, {'Class': '6.3,2.5,5.0,1.9,Iris-virginica'}, {'Class': '7.2,3.6,6.1,2.5,Iris-virginica'}, {'Class': '4.9,3.1,1.5,0.1,Iris-setosa'}, {'Class': '5.2,4.1,1.5,0.1,Iris-setosa'}, {'Class': '5.4,3.0,4.5,1.5,Iris-versicolor'}, {'Class': '5.7,2.8,4.5,1.3,Iris-versicolor'}, {'Class': '5.1,3.4,1.5,0.2,Iris-setosa'}, {'Class': '5.9,3.2,4.8,1.8,Iris-versicolor'}, {'Class': '6.7,3.3,5.7,2.5,Iris-virginica'}, {'Class': '5.1,2.5,3.0,1.1,Iris-versicolor'}, {'Class': '5.1,3.5,1.4,0.3,Iris-setosa'}, {'Class': '4.8,3.4,1.6,0.2,Iris-setosa'}, {'Class': '6.4,2.9,4.3,1.3,Iris-versicolor'}, {'Class': '6.8,2.8,4.8,1.4,Iris-versicolor'}, {'Class': '5.0,3.3,1.4,0.2,Iris-setosa'}, {'Class': '4.4,2.9,1.4,0.2,Iris-setosa'}, {'Class': '5.7,4.4,1.5,0.4,Iris-setosa'}, {'Class': '6.3,3.3,6.0,2.5,Iris-virginica'}, {'Class': '6.1,3.0,4.9,1.8,Iris-virginica'}, {'Class': '6.2,3.4,5.4,2.3,Iris-virginica'}, {'Class': '5.5,4.2,1.4,0.2,Iris-setosa' ...

# %%
def Classify(nItem, k, Items):
    if k>len(Items):
        # k is larger than list 
        # length, abort 
        return "k larger than list length"
    # Hold nearest neighbors. 
    # First item is distance,  
    # second class 
    neighbors=[]
    
    for item in Items:
        # Find Euclidean Distance 
        distance=EuclideanDistance(nItem,item)
        # Update neighbors, either adding 
        # the current item in neighbors  
        # or not. 
        neighbors=UpdateNeighbors(neighbors,item,distance,k)
    # Count the number of each 
    # class in neighbors     
    count=CalculateNeighborsClass(neighbors,k)
    # Find the max in count, aka the 
    # class with the most appearances. 
    return FindMax(count)
