# %%
import numpy as np
from numpy.polynomial import polynomial as P
from matplotlib import pyplot as plt

# %%
def white_noise(number, variance):
    noise = np.random.normal(loc=0.0, scale=variance, size=number)
    return noise

# %%
def linear_model(number):
    x = np.linspace(start=0.0, stop=2.0, num=number)
    x_power2 = np.power(x, 2)
    x_power3 = np.power(x, 3)
    x_power5 = np.power(x, 5)
    y = 0.2 - 1 * x + 0.9 * x_power2 + 0.7 * x_power3 - 0.2 * x_power5 + white_noise(number, 0.1)
    return y

# %%
y = linear_model(500)

# %%
plt.plot(y)
plt.show()
