# %%
#k nearest neigbors

#necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


#load iris dataset
names=('sepal_length','sepal_width','petal_length','petal_width','classifier')
iris_data=pd.read_csv("/home/biolove/machine learning/iris.data",header=None,index_col=False,names=names)
classifier=iris_data.classifier.tolist()
iris_data
classifier
# Out:
# ['Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
# ...
